# %% [markdown]
# <center> <img src="http://oci02.img.iteso.mx/identidad_de_instancia_2018/ITESO/Logos%20ITESO/Logo-ITESO-Principal.jpg" align="center" width="960" height="480"/> </center>

# %% [markdown]
# <center><font color=#555555><font size=6> MAF1731 - Microstructure and Trading Systems </font> <br> <br>
#
# <center><font color=#555555><font size=5> B.Eng Financial Engineering </font> <br> <br> <br> <br>
#
# <center><font color=#555555><font size=4> Team: </font> <br> <br>
#
# <center><font color=#555555><font size=3>  Lizbeth Alejandra Barragán Vazquez </font> <br><br>
# <center><font color=#555555><font size=3>  Chelsi Arelí Sedano Gómez </font> <br><br>
# <center><font color=#555555><font size=3>  Jorge Zuñiga Ortiz</font> <br><br>
# <center><font color=#555555><font size=3>  Jorge Varela Martinez</font> <br><br>
#
#
#
# <center> <font color= #555555> <font size = 4> Agost 2021 </a> | <font color= #555555> <font size = 4> Repository: <a href='https://github.com/chelsi122/Laboratorio1.git'>Link</a></font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <center> <font color= #555555> <font size = 6> Laboratory 1 </font> <br> <br> <font color= #555555> <font size = 5> Inversión de Capital  </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <br>

# %% [markdown]
# <font color= #555555> <font size = 4> Abstract </font>

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3>  Comparar los rendimientos obtenidos con un modelo de inversion pasivo y activo de un ETF con un capital de un millon de pesos. Para poder responder a una pregunta que cualquier inversionista se haría tal como ¿Qué estrategia de inversión me conviene más para poner a generar mis ingresos?</font>

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= #6B6B6B> <font size = 6> 1. Introduction </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> En el presente trabajo, se pretende realizar dos estrategias de inversión una pasiva y una activa, esto con la finalidad de observar cuál será la mejor opción para el millón de pesos que pone en juego el inversionista en curso. Todo esto será posible mediante el uso de un ETF.
# >
# > <font color= 'darkcyan' > <font size = 3> Para iniciar cabe destacar que un índice bursátil es un valor numérico, que se calcula según los precios de mercado de cada uno de los valores que componen ese índice en un momento determinado. La rentabilidad de un índice es la variación de su valor de un periodo a otro.
#     En pocas palabras, reflejan el comportamiento del mercado accionario o de diferentes empresas con las que se comparten similitudes operativas.
# >
# > <font color= 'darkcyan' > <font size = 3> Se utilizan como:
# >
# > <font color= 'darkcyan' > <font size = 3> - Indicadores de desempeño de una economía.
# >
# > <font color= 'darkcyan' > <font size = 3> - Medidas de aversión al riesgo.
# >
# > <font color= 'darkcyan' > <font size = 3> - Como referencia para estrategias de inversión.
# >
# > Posteriormente tenemos que:
# >
# > La inversión pasiva consiste en invertir en bolsa utilizando ETFs o fondos indexados, fondos que replican el comportamiento de cualquier índice bursátil (por ejemplo, podrías adquirir un fondo que replique el comportamiento del IBEX 35). Para este caso, se está haciendo uso del ETF IShare NAFTRAC mismo que busca replicar al índice del S&P500/BMV.
# >
# > La inversión activa se dedica a elegir acciones de forma individual para intentar batir la rentabilidad media del mercado.

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= #6B6B6B> 2. Objetives </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> Dentro de los objetivos, encontramos:
# >
# >  <font color= 'darkcyan' > <font size = 3> -  Comparar ambos tipos de inversión, pasiva y activa.
# >
# >  <font color= 'darkcyan' > <font size = 3> -  Comprobar los resultados por medio de una tabla que muestre los cambios al paso del tiempo respecto de las inversiones.
# >
# >  <font color= 'darkcyan' > <font size = 3> - Analizar la mejor oferta de inversión.

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= #6B6B6B> 3. Install/Load Packages and Functions </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# ## <font color= #6B6B6B> 3.1 Python Packages </font> <font color= #555555>

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> Para poder visualizar el presente notebook es necesario tener instaladas y/o en el archivo _requirements.txt_ las siguientes librerías:
# >
# > <font color= 'darkcyan' > <font size = 3> - Pandas
# >
# > <font color= 'darkcyan' > <font size = 3> - Numpy
# >
# > <font color= 'darkcyan' > <font size = 3> - Jupyter
# >
# > <font color= 'darkcyan' > <font size = 3> - Yfinance

# %% [markdown]
# ## <font color= #6E6E6E> 3.2 Install Packages</font>

# %%
# Librerías a utilizar
import numpy as np
import time
import pandas as pd
import yfinance as yf
from os.path import isfile, join
from os import listdir, path
from datetime import date
import matplotlib.pyplot as plt
import math
import Functions as fn

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.expand_frame_repr', False)

# %% [markdown]
# ## <font color= #6B6B6B> 3.3 Files Dependencies </font> <font color= #555555>

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> Para poder visualizar el presente notebook es necesario tener los siguientes archivos y dependencias:
# >
# > <font color= 'darkcyan' > <font size = 3> - files/precios.csv

# %% [markdown]
# ## <font color= #6B6B6B> 3.4 Python Functions </font> <font color= #555555>

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> Para poder visualizar el presente notebook es necesario correr las funciones procedentes:
# >
# > <font color= 'darkcyan' > <font size = 3> - f_files
# >
# > <font color= 'darkcyan' > <font size = 3> - f_datafiles
# >
# > <font color= 'darkcyan' > <font size = 3> - f_dates
# >
# > <font color= 'darkcyan' > <font size = 3> - f_tickers
# >
# > <font color= 'darkcyan' > <font size = 3> - f_down_data
# >
# > <font color= 'darkcyan' > <font size = 3> - f_sortdates
# >
# > <font color= 'darkcyan' > <font size = 3> - f_prices
# >
# > <font color= 'darkcyan' > <font size = 3> - f_posdata
# >
# > <font color= 'darkcyan' > <font size = 3> - f_passive_inv
# >
# > <font color= 'darkcyan' > <font size = 3> - f_passive

# %% [markdown]
# # <font color= #6B6B6B> 4. Data Description </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> Cabe desatacar que se cuenta con un capital de \$1,000,000 millón de pesos el cual se utilizará en la inversión procedente. Asimismo el porcentaje de comisiones que se cobrara con cada transacción será de 0.125\% sobre las ventas.

# %%
# Capital
k = 1000000
# Comision
c = 0.00125

# %%
# Path
abspath = path.abspath('files')

# %%
# Files
files = fn.f_files(abspath)

# %%
# Get into files
data_files = fn.f_datafiles(files)

# %%
# Extract dates
dates = fn.f_dates(files)

# %%
# Names in the BMV
tickers = fn.f_tickers(files, data_files)

# %% [markdown]
# # <font color= #6B6B6B> 5. Passive investment </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> Se realiza la descarga de datos desde yahoo finance y se obtiene lo siguiente.

# %%
# Download data
data_close = fn.f_down_data(tickers)
data_close.head(5)
# Out:
# [*********************100%***********************]  40 of 40 completed
#                  AC.MX   ALFAA.MX  ALPEKA.MX   ALSEA.MX    AMXL.MX    ASURB.MX  BBAJIOO.MX  BIMBOA.MX  BOLSAA.MX  CEMEXCPO.MX  CUERVO.MX  ELEKTRA.MX  FEMSAUBD.MX     GAPB.MX  GCARSOA1.MX      GCC.MX  GENTERA.MX  GFINBURO.MX  GFNORTEO.MX       RA.MX  GMEXICOB.MX    GMXT.MX   GRUMAB.MX  IENOVA.MX  KIMBERA.MX    LABB.MX  LALAB.MX  LIVEPOLC-1.MX  MEGACPO.MX   ORBIA.MX  NEMAKA.MX    OMAB.MX  PE&OLES.MX   PINFRA.MX       Q.MX  SITESB-1.MX  TLEVISACPO.MX   VESTA.MX  VOLARA.MX  WALMEX.MX
# Date
# ...

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> Se procede a realizar un DataFrame que muestra el precio de las acciones utilizadas en el periodo del 2018-01-31 junto con el porcentaje destinado sobre el capital respecto a la compra de cada activo, asimismo se presenta el total de títulos que se pueden comprar y la comisión que representa cada transacción.

# %%
sort_dates = fn.f_sortdates(data_close, dates)

prices = fn.f_prices(data_close, sort_dates)

act_delete = ['KOFL', 'KOFUBL', 'MXN', 'USD', 'NMKA', 'BSMXB']
posdata = fn.f_posdata(act_delete, data_files, files, prices, k, c)
posdata
# Out:
#            Ticker  Peso (%)     Precios  Titulos    Capital    Postura  Comisiones
# 0           AC.MX    0.0175  135.050003    129.0   17443.23   17421.45       21.78
# 1        ALFAA.MX    0.0268   23.360001   1145.0   26780.63   26747.20       33.43
# 2       ALPEKA.MX    0.0032   26.860001    118.0    3173.44    3169.48        3.96
# 3        ALSEA.MX    0.0083   60.880001    136.0    8290.03    8279.68       10.35
# 4         AMXL.MX    0.1331   17.440001   7622.0  133093.84  132927.68      166.16
# 5        ASURB.MX    0.0244  362.220001     67.0   24299.08   24268.74       30.34
# 6       BIMBOA.MX    0.0178   45.400002    391.0   17773.59   17751.40       22.19
# 7     CEMEXCPO.MX    0.0744   15.480000   4800.0   74396.88   74304.00       92.88
# 8       CUERVO.MX    0.0062   33.860001    182.0    6170.22    6162.52        7.70
# 9      ELEKTRA.MX    0.0136  672.390015     20.0   13464.61   13447.80       16.81
# ...

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> Se hace la obtención del cash o dinero bruto proveniente de los activos que se borraron en la variable llamada "act_delete".

# %%
# Cash 
cash = (1-posdata['Peso (%)'].sum())*k
cash
# Out:
# 41799.99999999995

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> Se realiza la sumatoria de las comisiones.

# %%
# Summatory of comisions
comision_sum = posdata['Comisiones'].sum()
comision_sum
# Out:
# 1194.6099999999997

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> Se obtiene un DataFrame final desde incio hasta el último dato proveniente de nuestra anterior descarga. Posteriormente se hace la distinción entre antes y durante pandemia.

# %%
passive_inv = {'Dates': ['2018-01-30'], 'Capital': [k]}
passive_inv = fn.f_passive_inv(sort_dates, posdata, prices, cash, passive_inv)

df_passive = fn.f_passive(passive_inv)
df_passive
# Out:
#          Dates     Capital  Rendimiento  Rendimiento Acumulado
# 0   2018-01-30  1000000.00     0.000000               0.000000
# 1   2018-01-31   997509.45    -0.002491              -0.002491
# 2   2018-02-28   942034.76    -0.055613              -0.058104
# 3   2018-03-28   917609.65    -0.025928              -0.084032
# 4   2018-04-30   960475.94     0.046715              -0.037317
# 5   2018-05-31   889204.38    -0.074204              -0.111521
# 6   2018-06-29   948581.68     0.066776              -0.044745
# 7   2018-07-31   984495.75     0.037861              -0.006884
# 8   2018-08-31   983131.68    -0.001386              -0.008270
# 9   2018-09-28   982183.72    -0.000964              -0.009234
# 10  2018-10-31   877525.19    -0.106557              -0.115791
# 11  2018-11-30   836790.20    -0.046420              -0.162212
# 12  2018-12-31   834491.99    -0.002746              -0.164958
# 13  2019-01-31   879096.25     0.053451              -0.111507
# ...

# %% [markdown]
# # <font color= #6B6B6B> 5.1 Results </font>

# %% [markdown]
# ## <font color= #6B6B6B> 5.1.1 Outcome of perfomance before the pandeminc </font>

# %%
# PRE PAN
df_passive_a = df_passive.loc[0:25]
df_passive_a
# Out:
#          Dates     Capital  Rendimiento  Rendimiento Acumulado
# 0   2018-01-30  1000000.00     0.000000               0.000000
# 1   2018-01-31   997509.45    -0.002491              -0.002491
# 2   2018-02-28   942034.76    -0.055613              -0.058104
# 3   2018-03-28   917609.65    -0.025928              -0.084032
# 4   2018-04-30   960475.94     0.046715              -0.037317
# 5   2018-05-31   889204.38    -0.074204              -0.111521
# 6   2018-06-29   948581.68     0.066776              -0.044745
# 7   2018-07-31   984495.75     0.037861              -0.006884
# 8   2018-08-31   983131.68    -0.001386              -0.008270
# 9   2018-09-28   982183.72    -0.000964              -0.009234
# 10  2018-10-31   877525.19    -0.106557              -0.115791
# 11  2018-11-30   836790.20    -0.046420              -0.162212
# 12  2018-12-31   834491.99    -0.002746              -0.164958
# 13  2019-01-31   879096.25     0.053451              -0.111507
# ...

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> Observamos que para antes de la pandemia bajo un caso de inversión pasiva, lo que se obtiene es mucho menor al monto que se invierte en un inicio. Por lo que viendo esos datos se podría decir que el haber realizado la inversión no fue satisfactorio.

# %% [markdown]
# ## <font color= #6B6B6B> 5.1.2 Outcome of perfomance during the pandeminc </font>

# %%
# DUR PAN
inv_passive_pos = {'Dates': ['2020-02-28'], 'Capital': [k]}
inv_passive_pos = fn.f_passive_inv(sort_dates[25:39], posdata, prices[25:39], cash, inv_passive_pos)
df_passive_b = fn.f_passive(inv_passive_pos)
df_passive_b
# Out:
#          Dates     Capital  Rendimiento  Rendimiento Acumulado
# 0   2020-02-28  1000000.00     0.000000               0.000000
# 1   2020-02-28   830928.55    -0.169071              -0.169071
# 2   2020-03-31   700812.54    -0.156591              -0.325663
# 3   2020-04-30   742482.09     0.059459              -0.266204
# 4   2020-05-29   735789.96    -0.009013              -0.275217
# 5   2020-06-30   765377.24     0.040212              -0.235005
# 6   2020-07-31   752206.27    -0.017208              -0.252214
# 7   2020-08-31   750307.03    -0.002525              -0.254739
# 8   2020-09-30   760368.93     0.013410              -0.241328
# 9   2020-10-30   753901.12    -0.008506              -0.249834
# 10  2020-11-30   850548.41     0.128196              -0.121638
# 11  2020-12-31   892915.64     0.049812              -0.071826
# 12  2021-01-29   871556.73    -0.023920              -0.095747
# 13  2021-02-26   908299.80     0.042158              -0.053589
# ...

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> De haber invertido durante la pandemia generada por COVID-19 en algunos meses se obtendrían rendimientos acumulados negativos, y se tendría un capital menor del monto inicial, sin embargo se nota que al final del periodo seguimos sin recuperar la inversión pero con un capital más grande que el que se obtiene para antes de pandemia bajo el esquema pasivo.

# %% [markdown]
# ## <font color= #6B6B6B> 5.2 Conclusion pasive investment </font>

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> En conclusión del apartado de inversión pasiva, podemos determinar que resulta mejor haberlo hecho durante la pandemia generada por COVID-19 que el haberlo hecho antes de la misma. Este hecho lo podemos atribuir a que muchos inversionistas al estar en sus hogares prefieren hacer inversiones que les resulten sencillas de manejar y al tener más tiempo para estar monitoreandolas deciden hacerlo en bolsa. Se puede ver como una operación oferta/demanda teniendo una mayor demanda de clientes al estar en pandemia que en anterioridad.

# %% [markdown]
# # <font color= #6B6B6B> 6. Active investment </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %%
# Obtener tickers 
tickers = posdata.iloc[:,0]
tickers = tickers.to_list()

# %%
# Descargar datos
data_close = fn.f_down_data(tickers)
sort_dates = fn.f_sortdates(data_close, dates)
prices = fn.f_prices(data_close, sort_dates)
# Out:
# [*********************100%***********************]  33 of 33 completed

# %%
# Portafolios creados para obtener el de mejor rendimiento
portfolios = fn.portfolios(prices)

# %%
# Seleccionar el portafolio con mayor sharpe
max_sharpe = portfolios.iloc[portfolios['Sharpe'].idxmax()]
max_sharpe = max_sharpe.to_list()
pesos1 = max_sharpe[3:]

# %% [markdown]
# # <font color= #6B6B6B> 6.1 Results </font>

# %%
# Obtener precios despues de pandemia
prices_post1 = prices.loc[prices.index >= "2020-02-28",:]
lista = prices_post1.index.values
capital = 1000000 - cash
#  Cambios porcentuales en pandemia
prices_post = prices.pct_change()
prices_post = prices_post[prices_post.index > "2020-02-28"]
lista2 = prices_post.index.values

# %%
# Se obtiene el portafolio a utilizar con los datos antes de pandemia
portfolio_1 = fn.portfolio_1(tickers, prices_post1, prices, posdata, pesos1, c, capital)
portfolio_1
# Out:
#                    Precios      Peso   Postura  Titulos  Comisiones
# Ticker
# AC.MX           107.989998  0.023080  22115.51    204.0       27.54
# ALFAA.MX         12.570000  0.010570  10128.14    805.0       12.65
# ALPEKA.MX        13.320000  0.015666  15011.59   1126.0       18.75
# ALSEA.MX         39.919998  0.007977   7643.57    191.0        9.53
# AMXL.MX          15.520000  0.044519  42657.88   2748.0       53.31
# ASURB.MX        324.890015  0.011296  10823.78     33.0       13.40
# BIMBOA.MX        29.690001  0.051069  48933.97   1648.0       61.16
# CEMEXCPO.MX       6.340000  0.013638  13068.26   2061.0       16.33
# CUERVO.MX        29.969999  0.042021  40264.54   1343.0       50.31
# ELEKTRA.MX     1327.579956  0.047594  45604.73     34.0       56.42
# FEMSAUBD.MX     159.210007  0.023308  22333.97    140.0       27.86
# GAPB.MX         213.660004  0.055325  53012.18    248.0       66.23
# GCARSOA1.MX      54.029999  0.034126  32699.39    605.0       40.86
# ...

# %%
# Restar comisiones 
cash = cash - portfolio_1["Comisiones"].sum()
cash
# Out:
# 40604.20999999995

# %%
# Crear columna de prices en post pandemia
prices_post1 = pd.DataFrame(prices_post.iloc[0,:])
prices_post1.columns = ["Porcentaje"]
prices_down = prices_post1[prices_post1.Porcentaje <= -.05 ]
down = list(prices_post.index.values)
prices_up = prices_post1[prices_post1.Porcentaje >= .05 ]
up = list(prices_up.index.values)

for i in range(13):
    word = pd.DataFrame(prices_post.iloc[i,:])
    word.columns = ["Porcentaje"]
    prices_down = word[word.Porcentaje <= -.05 ]
    down = list(word.index.values)
    prices_up = word[word.Porcentaje >= .05 ]
    up = list(word.index.values)

# %%
new_portfolio = fn.new_port(prices_post, tickers, prices, portfolio_1, c)
new_portfolio
# Out:
#                     Precio  Titulos anteriores  Nuevos Titulos    Nuevo Valor  Valor Venta  Comisiones venta
# Ticker
# AC.MX            92.830002               198.0           193.0   17916.190353       464.15          0.580187
# ALFAA.MX          9.860000               784.0           764.0    7533.039738       197.20          0.246500
# ALPEKA.MX        11.460000              1097.0          1069.0   12250.740041       320.88          0.401100
# ALSEA.MX         19.870001               186.0           181.0    3596.470152        99.35          0.124187
# AMXL.MX          14.600000              2679.0          2612.0   38135.200996       978.20          1.222750
# ASURB.MX        241.389999                32.0            31.0    7483.089981       241.39          0.301737
# BIMBOA.MX        35.590000              1606.0          1565.0   55698.350239      1459.19          1.823988
# ...

# %%
titulos_ant = []
new_cash = cash
valor_portafolio = []
all_data = pd.DataFrame()
acciones_venta = []
acciones_compra = []
comisiones_venta = []
comisiones_compra = []
for i in range(13):
    #Obtencion de rebalanceos
    word = pd.DataFrame(prices_post.iloc[i,:])
    word.columns = ["Porcentaje"]
    prices_down = word[word.Porcentaje <= -.05 ]
    down = list(prices_down.index.values)
    prices_up = word[word.Porcentaje >= .05 ]
    up = list(prices_up.index.values)
    #Creación de nuevos portafolios
    new_titulos = []
    new_portfolio = pd.DataFrame()
    new_portfolio["Ticker"] = tickers
    new_portfolio = new_portfolio.set_index("Ticker")
    new_portfolio["Precio"] = prices.iloc[26 + i,:].to_list() #Periodo de pandemia empieza en iloc 26
    
    if i == 0:
        new_portfolio["Titulos anteriores"] = portfolio_1.loc[:,"Titulos"].to_list()
    else:
        new_portfolio["Titulos anteriores"] = titulos_ant.to_list()
        
    #Venta de activos con descuento de precios
    for ticker in tickers:
        if ticker in down:
            n_titulos = new_portfolio.loc[ticker,"Titulos anteriores"] * .975
        else:
            n_titulos = new_portfolio.loc[ticker,"Titulos anteriores"]
        new_titulos.append(n_titulos) 
    new_portfolio["Nuevos Titulos"] = np.floor(new_titulos)
    new_portfolio["Valor Venta"] = np.round((new_portfolio["Titulos anteriores"] - new_portfolio["Nuevos Titulos"]) * new_portfolio["Precio"],2)
    acciones_venta.append(new_portfolio["Valor Venta"].sum())
    new_portfolio["Comisiones venta"] = new_portfolio["Valor Venta"] * c
    comisiones_venta.append(new_portfolio["Comisiones venta"].sum())
    #Manejo de efectivo despues de venta 
    new_cash = new_cash + new_portfolio["Valor Venta"].sum() - new_portfolio["Comisiones venta"].sum()
    
    #Compra de activos con aumento de precio
    valor_compra = []
    cash_buy = new_cash
    for ticker in tickers:
        if cash_buy>=0 and ticker in up:
            n_titulos = new_portfolio.loc[ticker,"Titulos anteriores"] * 1.025
            new_portfolio.loc[ticker,"Nuevos Titulos"] = np.floor(n_titulos)
            compra = np.round((new_portfolio.loc[ticker,"Titulos anteriores"] - new_portfolio.loc[ticker,"Nuevos Titulos"]) * new_portfolio.loc[ticker,"Precio"],2)*-1
            if compra > cash_buy:
                compra = 0
        else:
            compra = 0
        valor_compra.append(compra)
        cash_buy = cash_buy - compra
        
    new_portfolio["Valor Compra"] = valor_compra
    acciones_compra.append(new_portfolio["Valor Compra"].sum())
    titulos_ant = new_portfolio["Nuevos Titulos"]
    new_portfolio["Comisiones Compra"] = new_portfolio["Valor Compra"] * -c
    comisiones_compra.append(new_portfolio["Comisiones Compra"].sum()*-1)
    new_portfolio["Nuevo Valor"] = new_portfolio["Nuevos Titulos"] * new_portfolio["Precio"]
    
    #Manejo de efectivo despues de compra 
    new_cash = new_cash - new_portfolio["Valor Compra"].sum() + new_portfolio["Comisiones Compra"].sum()
    valor_portafolio.append(new_cash + new_portfolio["Nuevo Valor"].sum())

# %%
# Se obtiene el DataFrame propio de la inversión activa
df_activa = fn.df_activa(prices_post1, valor_portafolio, lista)
df_activa
# Out:
#     timestamp       capital  rendimiento  rendimiento_acumulado
# 0  2020-02-28  1.000000e+06          NaN                    NaN
# 1  2020-03-31  9.510619e+05    -0.051456              -0.051456
# 2  2020-04-30  1.025643e+06     0.072717               0.021261
# 3  2020-05-29  1.062411e+06     0.034608               0.055869
# 4  2020-06-30  1.134901e+06     0.063873               0.119742
# 5  2020-07-31  1.109385e+06    -0.023000               0.096741
# 6  2020-08-31  1.129813e+06     0.018081               0.114822
# 7  2020-09-30  1.152834e+06     0.019969               0.134792
# 8  2020-10-30  1.120123e+06    -0.029203               0.105589
# 9  2020-11-30  1.259509e+06     0.110667               0.216255
# 10 2020-12-31  1.361802e+06     0.075116               0.291372
# 11 2021-01-29  1.287664e+06    -0.057576               0.233795
# 12 2021-02-26  1.343181e+06     0.041333               0.275128
# 13 2021-03-31  1.421427e+06     0.055047               0.330176

# %%
# Se obtiene el DataFrame propio de las operaciones,
# indicando los títulos comprados, vendidos y las comisiones correspondientes

df_operaciones = fn.df_operaciones(lista2, acciones_compra, acciones_venta, comisiones_compra, comisiones_venta)
df_operaciones
# Out:
#     timestamp  titulos comprados / total operacion  titulos vendidos / total operacion  comisiones compra  comisiones venta  comisiones mes  comisiones acumuladas
# 0  2020-03-31                              1413.68                            18411.94           1.767100         23.014925       24.782025              24.782025
# 1  2020-04-30                             13692.53                             2388.18          17.115662          2.985225       20.100887              44.882913
# 2  2020-05-29                              9239.22                             2913.50          11.549025          3.641875       15.190900              60.073813
# 3  2020-06-30                             10375.25                             1130.77          12.969062          1.413463       14.382525              74.456338
# 4  2020-07-31                              6745.03                             6800.87           8.431287          8.501088       16.932375              91.388712
# ...

# %% [markdown]
# ## <font color= #6B6B6B> 6.2 Conclusion active investment </font>

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> Podemos notar como al hacerlo en inversión activa, los resultados para nuestro inversionista resultan más favorables que los obtenidos en pasiva. Esto lo podemos atribuir al hecho de que se toma a partir de un portafolio eficiente en el cual van cambiando las ponderaciones de acuerdo a los resultados obtenidos mes con mes.

# %% [markdown]
# ## <font color= #6B6B6B> 6.3 Medidas de atribución al desempeño </font>

# %%
# Se obtiene el DataFrame correspondiente a las medidas de desempeño
medidas = pd.DataFrame()
rend_m_m = [((df_activa["rendimiento"]*12).mean()-.0429),((df_passive_b["Rendimiento"]*12).mean()-.0429)]
rend_m_a = [df_activa["rendimiento_acumulado"][13],df_passive_b["Rendimiento Acumulado"][14]]
medidas["tipo de inversion"] = ["activa","pasiva"]
medidas["rend_m_m"] = rend_m_m
medidas["rend_m_a"] = rend_m_a
medidas.set_index("tipo de inversion")
# Out:
#                    rend_m_m  rend_m_a
# tipo de inversion
# activa             0.261877  0.330176
# pasiva            -0.041684  0.001520

# %% [markdown]
# # <font color= #6B6B6B> 7. Conclusion </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# > <font color= 'darkcyan' > <font size = 3> Finalmente, se puede observar como la mejor inversión resulta ser la activa confirmando una vez más que el hacer una inversión mediante un portafolio resulta ser una de las medidas que mejor se adaptan puesto que eliminamos los activos de mayor riesgo. Asimismo, se puede observar como las comisiones son relativamente bajas, por lo que las transacciones que se realizaban no disminuían nuestro capital en gran medida culminando en un mejor rendimiento.

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= #6B6B6B> 8. References </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# [1] Munnoz, 2020. Python project template. https://github.com/iffranciscome/python-project. (2021).
